# %%
#DataCamp Course : Data Scientist using Python 
#Module 1: Intro to Python for Data Science


#VARIABLES

# Create a variable savings
savings=100
type(savings)
# Print out savings
print(savings)


# Create a variable factor
factor = 1.10


# Calculate result
result = savings*(factor**7)


# Print out result
print(result)

# %%
#LISTS
#can have lists of lists in Python 
#can have different datatypes together in lists

# area variables (in square meters)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

# house information as list of lists
house = [["hallway", hall],
         ["kitchen", kit],
         ["living room", liv],
         ["bedroom", bed],
         ["bathroom", bath]]

# Print out house
print(house)

# Print out the type of house
print(type(house))

#Python has 0 based indexes in lists, so to retrieve the 2nd element in a list, name[1]
#name[3:5] will retrieve 4th and 5th element, NOT 6th as [start:end] is [inclusive:exclusive]

# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Print out second element from areas

print (areas[1])
# Print out last element from areas
print (areas[-1])

# Print out the area of the living room
print (areas[5])

# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Use slicing to create downstairs

#### To reference start of list simply leave it blank, similar for end of list as shown below
downstairs=areas[:6]
# Use slicing to create upstairs
upstairs=areas[6:]

# Print out downstairs and upstairs
print(downstairs)
print(upstairs)


#Subsetting lists within lists 

house = [['hallway', 11.25],
 ['kitchen', 18.0],
 ['living room', 20.0],
 ['bedroom', 10.75],
 ['bathroom', 9.5]]


print(house)

#to retrieve 2nd and 3rd nested list, all elements 
house[1:3][:]
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0], ['bedroom', 10.75], ['bathroom', 9.5]]
# <class 'list'>
# 11.25
# 9.5
# 20.0
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom', 9.5]
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0], ['bedroom', 10.75], ['bathroom', 9.5]]

# %%
#Changing List items

# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Correct the bathroom area
areas[9] = 10.50

# Change "living room" to "chill zone"
areas[4] = "chill zone"

# ADDING elements to list
# Create the areas list and make some changes
areas = ["hallway", 11.25, "kitchen", 18.0, "chill zone", 20.0,
         "bedroom", 10.75, "bathroom", 10.50]

# Add poolhouse data to areas, new list is areas_1
areas_1 = areas + ["poolhouse", 24.5]

# Add garage data to areas_1, new list is areas_2
areas_2 = areas_1 + ["garage", 15.45]


# DELETING ELEMENTS IN LIST
areas = ["hallway", 11.25, "kitchen", 18.0,
        "chill zone", 20.0, "bedroom", 10.75,
         "bathroom", 10.50, "poolhouse", 24.5,
         "garage", 15.45]

#to delete poolhouse and its area, this works
del(areas[10:12])

#or this works too: del(areas[-4:-2])

# !!!!!!NOTE ON INNER WORKING OF LISTS:
# say x and y are 2 lists
# y = x will assign common reference points to both x and y, so changes in y WILL REFLECT in x
# to copy lists without affecting the parent, y = x[:] or y = list(x)

# Create list areas
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Create areas_copy
areas_copy = areas[:]

# Change areas_copy
areas_copy[0] = 5.0

# Print areas
print(areas)
# Out:
# [['kitchen', 18.0], ['living room', 20.0]]

# %%
# FUNCTIONS IN PYTHON
# Some basic functions introduced in the course: round(), max(), complex(), sorted(iterable, key=None, reverse=False)

# METHODS IN PYTHON
# Methods are like functions which are specific to objects: like float specific methods, list specific methods, etc. 
# Methods are called like so: objectName.methodName 
# For example: 

name = "liz"
name.capitalize() #capitalizes first letter of name
name.replace("z", "sa") #liz to lisa, bitches 

# string to experiment with: room
room = "poolhouse"

# Use upper() on room: room_up
room_up=room.upper()

# Print out room and room_up
print(room)
print(room_up)
#(different outputs)

# Print out the number of o's in room
print(room.count("o"))


# Create list areas
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# INDEX method
# Print out the index of the element 20.0
print(areas.index(20.0))

# COUNT Method
# Print out how often 14.5 appears in areas
print(areas.count(14.5))

# Create list areas
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# APPEND Method
# Use append twice to add poolhouse and garage size
areas.append(24.5)
areas.append(15.45)


# Print out areas
print(areas)

# REVERSE method
# Reverse the orders of the elements in areas
areas.reverse()

# Print out areas
print(areas)
# Out:
# 'lisa'

# %%
# IMPORTING PACKAGES!!!!

# various ways of doing it
# import numpy
# if you import like so ^, you will have to use numpy.array etc to access functions inside the package

# import numpy as np
# now we can use a shorthand : np.array

# to import only specific functions explicitly: 
# from numpy import array 
# we can then use array function call without a prefix

# we also can do more complicated stuff, just for the heck of it, like:
# from numpy import array as lalala 
# you can then call the array fuction by lalala instead of array (... I know ...)

# %%
# some more basic shizzz from DataCamp (you can tell i'm losing patience at this time)

# Definition of radius
r = 0.43

# Import the math package
import math 

# Calculate C
C = math.pi*r*2

# Calculate A
A = math.pi*(r**2)

# Build printout
print("Circumference: " + str(C))
print("Area: " + str(A))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-2d95372621aa> in <module>()
#       1
# ----> 2 import sklearn as sk
#
# ImportError: No module named 'sklearn'

# %%
# INTRODUUUUUUCIIIIING!!! NumPy (or Numeric Python)

# We need this because Lists in Python SUCK when it comes to manipulating a bunch values together (yay R)

# NumPy arrays HAVE TO BE OF THE SAME TYPE!!!! 

# NumPy subsetting

# bmi[1]        -> returns 2nd element
# bmi > 23      -> returns boolean array with T/F according to values
# bmi[bmi > 23] -> returns values > 23



# MOAR BASIC STUFF FROM DATA CAMP
# height is available as a regular list

# Import numpy
import numpy as np

# Create a numpy array from height: np_height
np_height = np.array(height)

# Print out np_height
print(height)

# Convert np_height to m: np_height_m
np_height_m = np_height*0.0254

# Print np_height_m
print(np_height_m)


# LIGHTWEIGHT!!!!!

# height and weight are available as a regular lists

# Import numpy
import numpy as np

# Calculate the BMI: bmi
np_height_m = np.array(height) * 0.0254
np_weight_kg = np.array(weight) * 0.453592
bmi = np_weight_kg / np_height_m ** 2

# Create the light array

light = bmi < 21

# Print out light
print(light)

# Print out BMIs of all baseball players whose BMI is below 21
# LOOK BELOW! 
print(bmi[light])


# SUBSETTING NumPy arrays

# height and weight are available as a regular lists

# Import numpy
import numpy as np

# Store weight and height lists as numpy arrays
np_weight = np.array(weight)
np_height = np.array(height)

# Print out the weight at index 50
print(np_weight[50])

# Print out sub-array of np_height: index 100 up to and including index 110
print(np_height[100:111])

# SUBSETTING IN 2D NumPy arrays (yay, this is like R)
# np_2d[0][2] 
# np_2d[0,2] 
# Both of the above return 1st row 3rd element

# EXAMPLES ON SUBSETTING 2D NumPy arrays
# baseball is available as a regular list of lists

# Import numpy package
import numpy as np

# Create np_baseball (2 cols)
np_baseball = np.array(baseball)

# Print out the 50th row of np_baseball
print(np_baseball[49, :])

# Select the entire second column of np_baseball: np_weight
np_weight = np_baseball[:,1]

# Print out height of 124th player
print(np_baseball[123,0])

#MORE STUFF ON 2D NumPY arrays, we now have a 3rd column for AGE (yay?)

# baseball is available as a regular list of lists
# updated is available as 2D numpy array

# Import numpy package
import numpy as np

# Create np_baseball (3 cols)
np_baseball = np.array(baseball)

# Print out addition of np_baseball and updated
print(np_baseball + updated)

# THIS IS HOW YOU CREATE NEW NUMPY ARRAYS
# Create numpy array: conversion
conversion = np.array([0.0254, 0.453592, 1])

# Print out product of np_baseball and conversion
print(np_baseball*conversion)

# %%
#CREATING DATA : NumPy has something like rnorm, it is : np.random.normal(mean, sd, no of samples)

numbers = np.round(np.random.normal(0,1,100),2)
numbers


# "PRO TIP FOR DATA SCIENTISTS" median is better than mean to deal with outliers.... Stats101

# np_baseball is available

# Import numpy
import numpy as np

# Create np_height from np_baseball
np_height = np_baseball[:, 0]

# Print out the mean of np_height
print(np.mean(np_height))

# Print out the median of np_height
print(np.median(np_height))


#(the median is more like it...)


# MORE BASIC STATS USING NUMPY, like std dev (std), correlation coefficient ()
# np_baseball is available

# Import numpy
import numpy as np

# Print mean height (first column)
avg = np.mean(np_baseball[:,0])
print("Average: " + str(avg))

# Print median height. Replace 'None'
med = np.median(np_baseball[:,0])
print("Median: " + str(med))

# Print out the standard deviation on height. Replace 'None'
stddev = np.std(np_baseball[:,0])
print("Standard Deviation: " + str(stddev))

# Print out correlation between first and second column. Replace 'None'
corr = np.corrcoef(np_baseball[:,0], np_baseball[:,1])
print("Correlation: " + str(corr))


# PRO TIP : corrcoef returns the covariance matrix of all xx xy yx yy, hence the 2D array! useful for checking
# ..correlations between 3 elements etc

# heights and positions are available as lists


#NumPy final exercise

# Import numpy
import numpy as np

# Convert positions and heights to numpy arrays: np_positions, np_heights
np_positions = np.array(positions)
np_heights = np.array(heights)


# Heights of the goalkeepers: gk_heights
gk_heights = np_heights[np_positions == 'GK']

# Heights of the other players: other_heights
other_heights = np_heights[np_positions != 'GK']

# Print out the median height of goalkeepers. Replace 'None'
print("Median height of goalkeepers: " + str(np.median(gk_heights)))

# Print out the median height of other players. Replace 'None'
print("Median height of other players: " + str(np.median(other_heights)))
# Out:
# array([-0.23, -1.15, -0.56, -1.12, -0.91,  0.73, -1.43,  0.8 ,  0.04,
#        -0.7 , -2.02,  0.58, -0.31, -0.68,  0.25, -1.24, -0.5 , -0.52,
#        -0.05, -0.41, -0.5 ,  0.46,  1.05,  0.91, -0.62,  0.82, -0.57,
#         0.94,  0.96, -0.12, -0.29,  0.04, -1.39,  0.05, -0.68, -0.86,
#        -0.52, -1.1 ,  0.38,  0.85, -1.41,  1.12,  3.5 ,  0.17,  0.02,
#         0.93,  1.23,  1.68,  1.14,  1.01, -1.24,  0.66, -0.99, -1.66,
#         1.01, -1.45,  0.62, -0.73, -0.03,  0.33,  1.5 ,  0.81,  0.01,
#         0.14, -2.07,  0.9 , -0.59, -2.49, -0.93, -0.11,  0.21, -0.12,
#        -1.25, -0.02, -0.64,  0.82,  0.35, -0.32, -0.02, -0.16, -0.83,
#         0.55, -0.65, -1.61,  0.54,  1.16, -0.66,  0.54, -0.05, -0.65,
#         0.19, -0.55,  0.91,  0.58, -0.63, -1.68, -0.84, -1.41,  0.26,  0.1 ])
